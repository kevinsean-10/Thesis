# %%
import numpy as np
from itertools import product,combinations
import matplotlib.pyplot as plt

# %%
epsilon = 1e-2
delta = 0.01
m = 100
gen_max = 300
dim = 2
mutation_factor=0.1
crossover_rate=0.5
seed = 0

# how many parts/slices do you desire in each dimension?
parts = 100

def system_eq(x):
    f1 = np.exp(x[0]-x[1])-np.sin(x[0]+x[1])
    f2 = (x[0]*x[1])**2-np.cos(x[0]+x[1])
    return np.array([f1,f2])

boundaries = np.array([(-10,10) for _ in range (dim)])

# %%
def objective_function(x:np.ndarray):
    F_array = system_eq(x)
    denom = 0
    for f in F_array:
        denom +=np.abs(f)
    F = 1/(1+denom)
    return -F

# %%
def slice_hypercube(lower_bounds, upper_bounds, interval, dim):
    # Create a list of arrays, each containing points spaced h apart for each dimension
    points = [np.arange(lower_bounds[i], upper_bounds[i], interval) for i in range(dim)]
    
    # Use meshgrid to create a grid of points in n-dimensional space
    grids = np.meshgrid(*points, indexing='ij')
    
    # Flatten and combine the grid points into a single 2D array
    grid_points = np.vstack([grid.ravel() for grid in grids]).T
    
    # Generate all vertices for smaller hypercubes within each grid cell
    return np.array([grid_points + offset for offset in product([0, interval], repeat=dim)])

# %%
# length of each parts in each dimension
inc_int = (boundaries[0,1]-boundaries[0,0])/parts

# Hypercubes
hypercubes_edges = slice_hypercube(lower_bounds=boundaries[:,0],
                    upper_bounds=boundaries[:,1],
                    interval=inc_int,
                    dim=dim)

# %%
cluster = []
for hypercube_id in range(hypercubes_edges.shape[1]):
    X0 = hypercubes_edges[:,hypercube_id,:]
    F_list = system_eq(X0.T)

    # cek jika f yang berubah tanda dari F_list jika dievaluasi di tiap edge hypercube
    product_combination = np.array([[a*b for a,b in combinations(F_list[i],2)] for i in range (F_list.shape[0])])

    # jika semua f dari F_list berubah tanda jika dievaluasi di tiap edge hypercube, maka ada akar di situ
    change_sign = np.array([np.any(product_combination[i]<0) for i in range (product_combination.shape[0])])
    if np.all(change_sign==True):
        # print(f'Ada akar di sini: \nX0={X0}')
        cluster.append(X0)

cluster = np.array(cluster)
print(f"Number of clusters containing root: {cluster.shape[0]}")
# Out:
# Number of clusters containing root: 12

# %% [markdown]
# # DE Evaluation

# %%
import importlib
import re

import sys
module_path = r"D:\OneDrive - Institut Teknologi Bandung\[AKADEMIK]\Semester 7-8\TA\Thesis\Differential Evolution"
sys.path.append(module_path)
import deal as dl
importlib.reload(dl)

sys.path.remove(module_path)

# %%
roots = []
values = []
for i in range (cluster.shape[0]):
    subbound = np.array([[cluster[i,:,:][:,d].min(),cluster[i,:,:][:,d].max()] for d in range(cluster.shape[2])])
    root,value = dl.differensial_evolution(objective_func=objective_function,
                                           population_size=m,
                                           boundaries=subbound, 
                                           gen_max=gen_max, 
                                           mutation_factor=mutation_factor, 
                                           crossover_rate=crossover_rate,
                                           seed=0,
                                           print_gen = True,
                                           history = False)
    roots.append(root)
    values.append(value)

archive = np.array(roots)
scores = np.array(values)
print(f'Number of Clusters containing root: {cluster.shape[0]}\n')
print(f'Roots:\n{archive}\n\nValues: \n{values}')
# Out:
# =========Generation 0=========
# Best Point:[-6.4478125  0.1553125] with score -0.9866137684079332
# =========Generation 1=========
# Best Point:[-6.4478125  0.1553125] with score -0.9866137684079332
# =========Generation 2=========
# Best Point:[-6.44306484  0.15484406] with score -0.9890806559463396
# =========Generation 3=========
# Best Point:[-6.44306484  0.15484406] with score -0.9890806559463396
# =========Generation 4=========
# Best Point:[-6.44306484  0.15484406] with score -0.9890806559463396
# =========Generation 5=========
# Best Point:[-6.43234761  0.15577727] with score -0.9907942062649057
# =========Generation 6=========
# Best Point:[-6.4359204   0.15544812] with score -0.9977567719681275
# =========Generation 7=========
# Best Point:[-6.4359204   0.15544812] with score -0.9977567719681275
# =========Generation 8=========
# Best Point:[-6.43756855  0.15532129] with score -0.9993517982990474
# =========Generation 9=========
# Best Point:[-6.4369469   0.15535034] with score -0.999747211167121
# =========Generation 10=========
# Best Point:[-6.4369469   0.15535034] with score -0.999747211167121
# =========Generation 11=========
# Best Point:[-6.4369469   0.15535034] with score -0.999747211167121
# =========Generation 12=========
# Best Point:[-6.4369469   0.15535034] with score -0.999747211167121
# =========Generation 13=========
# Best Point:[-6.43715659  0.15534042] with score -0.9999006219327417
# =========Generation 14=========
# Best Point:[-6.43715659  0.15534042] with score -0.9999006219327417
# =========Generation 15=========
# Best Point:[-6.43715659  0.15534042] with score -0.9999006219327417
# =========Generation 16=========
# Best Point:[-6.43715659  0.15534042] with score -0.9999006219327417
# =========Generation 17=========
# Best Point:[-6.43715659  0.15534042] with score -0.9999006219327417
# =========Generation 18=========
# Best Point:[-6.43714927  0.15534648] with score -0.9999660337100509
# =========Generation 19=========
# Best Point:[-6.43714927  0.15534648] with score -0.9999660337100509
# =========Generation 20=========
# Best Point:[-6.43715761  0.15534661] with score -0.999978416309854
# =========Generation 21=========
# Best Point:[-6.43715883  0.15534675] with score -0.9999817462501555
# =========Generation 22=========
# Best Point:[-6.43715659  0.15534816] with score -0.9999918630725584
# =========Generation 23=========
# Best Point:[-6.43715984  0.15534788] with score -0.9999964673033033
# =========Generation 24=========
# Best Point:[-6.43715984  0.15534788] with score -0.9999964673033033
# =========Generation 25=========
# Best Point:[-6.43716278  0.15534793] with score -0.9999990724891662
# =========Generation 26=========
# Best Point:[-6.43716278  0.15534793] with score -0.9999990724891662
# =========Generation 27=========
# Best Point:[-6.43716278  0.15534793] with score -0.9999990724891662
# =========Generation 28=========
# Best Point:[-6.43716271  0.15534788] with score -0.9999998278944809
# =========Generation 29=========
# Best Point:[-6.43716271  0.15534788] with score -0.9999998278944809
# =========Generation 30=========
# Best Point:[-6.43716271  0.15534788] with score -0.9999998278944809
# =========Generation 31=========
# Best Point:[-6.43716271  0.15534788] with score -0.9999998278944809
# =========Generation 32=========
# Best Point:[-6.43716271  0.15534788] with score -0.9999998278944809
# =========Generation 33=========
# Best Point:[-6.43716269  0.15534787] with score -0.9999998680143868
# =========Generation 34=========
# Best Point:[-6.43716269  0.15534787] with score -0.9999998680143868
# =========Generation 35=========
# Best Point:[-6.43716259  0.15534787] with score -0.9999999862615565
# =========Generation 36=========
# Best Point:[-6.43716259  0.15534787] with score -0.9999999862615565
# =========Generation 37=========
# Best Point:[-6.43716259  0.15534787] with score -0.9999999862615565
# =========Generation 38=========
# Best Point:[-6.43716259  0.15534787] with score -0.9999999862615565
# =========Generation 39=========
# Best Point:[-6.43716259  0.15534787] with score -0.9999999866310754
# =========Generation 40=========
# Best Point:[-6.43716259  0.15534787] with score -0.9999999866310754
# =========Generation 41=========
# Best Point:[-6.43716258  0.15534787] with score -0.9999999872387183
# =========Generation 42=========
# Best Point:[-6.43716259  0.15534787] with score -0.9999999888726457
# =========Generation 43=========
# Best Point:[-6.43716259  0.15534787] with score -0.9999999888726457
# =========Generation 44=========
# Best Point:[-6.43716258  0.15534788] with score -0.9999999965311093
# =========Generation 45=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999965813329
# =========Generation 46=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999965813329
# =========Generation 47=========
# Best Point:[-6.43716259  0.15534788] with score -0.999999998545688
# =========Generation 48=========
# Best Point:[-6.43716259  0.15534788] with score -0.999999998545688
# =========Generation 49=========
# Best Point:[-6.43716259  0.15534788] with score -0.999999998545688
# =========Generation 50=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999992927027
# =========Generation 51=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999992927027
# =========Generation 52=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999998445313
# =========Generation 53=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999998445313
# =========Generation 54=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999998822371
# =========Generation 55=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999998822371
# =========Generation 56=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999720033
# =========Generation 57=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999767348
# =========Generation 58=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999767348
# =========Generation 59=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999929803
# =========Generation 60=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999929803
# =========Generation 61=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999940621
# =========Generation 62=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999940621
# =========Generation 63=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999940621
# =========Generation 64=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999973361
# =========Generation 65=========
# Best Point:[-6.43716259  0.15534788] with score -0.999999999998638
# =========Generation 66=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999997566
# =========Generation 67=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999997566
# =========Generation 68=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999997566
# =========Generation 69=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999997566
# =========Generation 70=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999997755
# =========Generation 71=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999997755
# =========Generation 72=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999998879
# =========Generation 73=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999047
# =========Generation 74=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999394
# =========Generation 75=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999616
# =========Generation 76=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999734
# =========Generation 77=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999811
# =========Generation 78=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999905
# =========Generation 79=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999905
# =========Generation 80=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999913
# =========Generation 81=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999947
# =========Generation 82=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999947
# =========Generation 83=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999987
# =========Generation 84=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999987
# =========Generation 85=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999993
# =========Generation 86=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999993
# =========Generation 87=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 88=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 89=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 90=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 91=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 92=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 93=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 94=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 95=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 96=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 97=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 98=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 99=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 100=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 101=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 102=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 103=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 104=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 105=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 106=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 107=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 108=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 109=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 110=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 111=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 112=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 113=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 114=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 115=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 116=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 117=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 118=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 119=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 120=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 121=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 122=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 123=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 124=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 125=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 126=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 127=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 128=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 129=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 130=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 131=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 132=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 133=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 134=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 135=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 136=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 137=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 138=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 139=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 140=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 141=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 142=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 143=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 144=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 145=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 146=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 147=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 148=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 149=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 150=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 151=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 152=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 153=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 154=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 155=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 156=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 157=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 158=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 159=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 160=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 161=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 162=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 163=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 164=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 165=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 166=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 167=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 168=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 169=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 170=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 171=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 172=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 173=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 174=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 175=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 176=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 177=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 178=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 179=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 180=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 181=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 182=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 183=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 184=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 185=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 186=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 187=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 188=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 189=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 190=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 191=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 192=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 193=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 194=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 195=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 196=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 197=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 198=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 199=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 200=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 201=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 202=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 203=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 204=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 205=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 206=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 207=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 208=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 209=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 210=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 211=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 212=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 213=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 214=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 215=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 216=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 217=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 218=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 219=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 220=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 221=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 222=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 223=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 224=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 225=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 226=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 227=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 228=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 229=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 230=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 231=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 232=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 233=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 234=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 235=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 236=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 237=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 238=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 239=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 240=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 241=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 242=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 243=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 244=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 245=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 246=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 247=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 248=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 249=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 250=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 251=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 252=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 253=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 254=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 255=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 256=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 257=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 258=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 259=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 260=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 261=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 262=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 263=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 264=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 265=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 266=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 267=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 268=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 269=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 270=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 271=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 272=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 273=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 274=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 275=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 276=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 277=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 278=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 279=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 280=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 281=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 282=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 283=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 284=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 285=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 286=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 287=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 288=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 289=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 290=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 291=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 292=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 293=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 294=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 295=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 296=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 297=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 298=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 299=========
# Best Point:[-6.43716259  0.15534788] with score -0.9999999999999996
# =========Generation 0=========
# Best Point:[-6.23125 -0.15625] with score -0.8672812072146255
# =========Generation 1=========
# Best Point:[-6.23132813 -0.16046875] with score -0.8956828160565661
# =========Generation 2=========
# Best Point:[-6.21703609 -0.1591405 ] with score -0.8992814549772357
# =========Generation 3=========
# Best Point:[-6.20500313 -0.16095095] with score -0.9209175301907709
# =========Generation 4=========
# Best Point:[-6.20500313 -0.16095095] with score -0.9209175301907709
# =========Generation 5=========
# Best Point:[-6.20500313 -0.16095095] with score -0.9209175301907709
# =========Generation 6=========
# Best Point:[-6.20339726 -0.16080718] with score -0.9217286533123688
# =========Generation 7=========
# Best Point:[-6.20339726 -0.16080718] with score -0.9217286533123688
# =========Generation 8=========
# Best Point:[-6.20360332 -0.16096898] with score -0.9223731056594725
# =========Generation 9=========
# Best Point:[-6.20019322 -0.16075583] with score -0.9228488902421487
# =========Generation 10=========
# Best Point:[-6.20060439 -0.16104495] with score -0.9250720425080758
# =========Generation 11=========
# Best Point:[-6.20060439 -0.16104495] with score -0.9250720425080758
# =========Generation 12=========
# Best Point:[-6.20041031 -0.16104211] with score -0.925336391415134
# =========Generation 13=========
# Best Point:[-6.20041031 -0.16104211] with score -0.925336391415134
# =========Generation 14=========
# Best Point:[-6.20041031 -0.16104211] with score -0.925336391415134
# =========Generation 15=========
# Best Point:[-6.20041031 -0.16104211] with score -0.925336391415134
# =========Generation 16=========
# Best Point:[-6.20021414 -0.16101841] with score -0.9254054939660273
# =========Generation 17=========
# Best Point:[-6.20026693 -0.16102949] with score -0.9254873292019989
# =========Generation 18=========
# Best Point:[-6.20011849 -0.16104607] with score -0.9256392597774823
# =========Generation 19=========
# Best Point:[-6.20011849 -0.16104607] with score -0.9256392597774823
# =========Generation 20=========
# Best Point:[-6.20009086 -0.16104494] with score -0.9256852465844249
# =========Generation 21=========
# Best Point:[-6.20009086 -0.16104494] with score -0.9256852465844249
# =========Generation 22=========
# Best Point:[-6.20007115 -0.16104322] with score -0.9257219505253803
# =========Generation 23=========
# Best Point:[-6.20000078 -0.16104111] with score -0.9257370969781903
# =========Generation 24=========
# Best Point:[-6.20000131 -0.16104409] with score -0.9257661026917813
# =========Generation 25=========
# Best Point:[-6.20000131 -0.16104409] with score -0.9257661026917813
# =========Generation 26=========
# Best Point:[-6.20000131 -0.16104409] with score -0.9257661026917813
# =========Generation 27=========
# Best Point:[-6.20000421 -0.16104592] with score -0.9257775022646938
# =========Generation 28=========
# Best Point:[-6.20000421 -0.16104592] with score -0.9257775022646938
# =========Generation 29=========
# Best Point:[-6.20000114 -0.16104606] with score -0.9257795145424791
# =========Generation 30=========
# Best Point:[-6.20000262 -0.16104576] with score -0.9257811963277439
# =========Generation 31=========
# Best Point:[-6.20000262 -0.16104576] with score -0.9257811963277439
# =========Generation 32=========
# Best Point:[-6.20000262 -0.16104576] with score -0.9257811963277439
# =========Generation 33=========
# Best Point:[-6.20000262 -0.16104576] with score -0.9257811963277439
# =========Generation 34=========
# Best Point:[-6.20000262 -0.16104576] with score -0.9257811963277439
# =========Generation 35=========
# Best Point:[-6.20000262 -0.16104576] with score -0.9257811963277439
# =========Generation 36=========
# Best Point:[-6.20000262 -0.16104576] with score -0.9257811963277439
# =========Generation 37=========
# Best Point:[-6.20000262 -0.16104576] with score -0.9257811963277439
# =========Generation 38=========
# Best Point:[-6.20000262 -0.16104576] with score -0.9257811963277439
# =========Generation 39=========
# Best Point:[-6.20000262 -0.16104576] with score -0.9257811963277439
# =========Generation 40=========
# Best Point:[-6.20000129 -0.16104585] with score -0.9257817185650461
# =========Generation 41=========
# Best Point:[-6.20000114 -0.16104578] with score -0.9257827309798211
# =========Generation 42=========
# Best Point:[-6.2000008  -0.16104581] with score -0.9257827964658222
# =========Generation 43=========
# Best Point:[-6.20000081 -0.16104579] with score -0.9257830143482213
# =========Generation 44=========
# Best Point:[-6.20000051 -0.16104581] with score -0.9257831448985016
# =========Generation 45=========
# Best Point:[-6.20000035 -0.16104581] with score -0.9257833429137493
# =========Generation 46=========
# Best Point:[-6.20000006 -0.1610458 ] with score -0.9257834936122347
# =========Generation 47=========
# Best Point:[-6.20000006 -0.1610458 ] with score -0.9257834936122347
# =========Generation 48=========
# Best Point:[-6.20000022 -0.16104581] with score -0.9257835207233149
# =========Generation 49=========
# Best Point:[-6.20000004 -0.1610458 ] with score -0.9257835685554593
# =========Generation 50=========
# Best Point:[-6.2        -0.16104581] with score -0.9257836232594195
# =========Generation 51=========
# Best Point:[-6.20000004 -0.16104581] with score -0.9257836598449622
# =========Generation 52=========
# Best Point:[-6.20000004 -0.16104581] with score -0.9257836598449622
# =========Generation 53=========
# Best Point:[-6.20000001 -0.16104581] with score -0.9257836846872672
# =========Generation 54=========
# Best Point:[-6.20000001 -0.16104581] with score -0.9257836929776273
# =========Generation 55=========
# Best Point:[-6.20000001 -0.16104581] with score -0.9257836929776273
# =========Generation 56=========
# Best Point:[-6.2        -0.16104581] with score -0.9257836968826936
# =========Generation 57=========
# Best Point:[-6.2        -0.16104581] with score -0.9257836968826936
# =========Generation 58=========
# Best Point:[-6.2        -0.16104581] with score -0.9257836968826936
# =========Generation 59=========
# Best Point:[-6.2        -0.16104581] with score -0.9257836970860421
# =========Generation 60=========
# Best Point:[-6.2        -0.16104581] with score -0.9257836993503963
# =========Generation 61=========
# Best Point:[-6.2        -0.16104581] with score -0.9257836993503963
# =========Generation 62=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837021462034
# =========Generation 63=========
# Best Point:[-6.2        -0.16104581] with score -0.925783702986649
# =========Generation 64=========
# Best Point:[-6.2        -0.16104581] with score -0.925783702986649
# =========Generation 65=========
# Best Point:[-6.2        -0.16104581] with score -0.925783702986649
# =========Generation 66=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837032357429
# =========Generation 67=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837032357429
# =========Generation 68=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837032357429
# =========Generation 69=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837032357429
# =========Generation 70=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837032357429
# =========Generation 71=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837032689613
# =========Generation 72=========
# Best Point:[-6.2        -0.16104581] with score -0.92578370327336
# =========Generation 73=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033025088
# =========Generation 74=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033025088
# =========Generation 75=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033025088
# =========Generation 76=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033030791
# =========Generation 77=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033030791
# =========Generation 78=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033108006
# =========Generation 79=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033122064
# =========Generation 80=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033172933
# =========Generation 81=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033180211
# =========Generation 82=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033180211
# =========Generation 83=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033189081
# =========Generation 84=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033204209
# =========Generation 85=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703320968
# =========Generation 86=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033212066
# =========Generation 87=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033212066
# =========Generation 88=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033222397
# =========Generation 89=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033222397
# =========Generation 90=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033222597
# =========Generation 91=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033222597
# =========Generation 92=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033223428
# =========Generation 93=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322532
# =========Generation 94=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322532
# =========Generation 95=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033225685
# =========Generation 96=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033225685
# =========Generation 97=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033225685
# =========Generation 98=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033225893
# =========Generation 99=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226011
# =========Generation 100=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226011
# =========Generation 101=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226011
# =========Generation 102=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226152
# =========Generation 103=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226152
# =========Generation 104=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322616
# =========Generation 105=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226174
# =========Generation 106=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226174
# =========Generation 107=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226174
# =========Generation 108=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226174
# =========Generation 109=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226174
# =========Generation 110=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226174
# =========Generation 111=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226182
# =========Generation 112=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226187
# =========Generation 113=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226187
# =========Generation 114=========
# Best Point:[-6.2        -0.16104581] with score -0.9257837033226187
# =========Generation 115=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 116=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 117=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 118=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 119=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 120=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 121=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 122=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 123=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 124=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 125=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 126=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 127=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 128=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 129=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 130=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 131=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 132=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 133=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 134=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 135=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 136=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 137=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 138=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 139=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 140=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 141=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 142=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 143=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 144=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 145=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 146=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 147=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 148=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 149=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 150=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 151=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 152=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 153=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 154=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 155=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 156=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 157=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 158=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 159=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 160=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 161=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 162=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 163=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 164=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 165=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 166=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 167=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 168=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 169=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 170=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 171=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 172=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 173=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 174=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 175=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 176=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 177=========
# Best Point:[-6.2        -0.16104581] with score -0.925783703322619
# =========Generation 178=========
# ...
# =========Generation 113=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 114=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 115=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 116=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 117=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 118=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 119=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 120=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 121=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 122=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 123=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 124=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 125=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 126=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 127=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 128=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 129=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 130=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 131=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 132=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 133=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 134=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 135=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 136=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 137=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 138=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 139=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 140=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 141=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 142=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 143=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 144=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 145=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 146=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 147=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 148=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 149=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 150=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 151=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 152=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 153=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 154=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 155=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 156=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 157=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 158=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 159=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 160=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 161=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 162=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 163=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 164=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 165=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 166=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 167=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 168=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 169=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 170=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 171=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 172=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 173=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 174=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 175=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 176=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 177=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 178=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 179=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 180=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 181=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 182=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 183=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 184=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 185=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 186=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 187=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 188=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 189=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 190=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 191=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 192=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 193=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 194=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 195=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 196=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 197=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 198=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 199=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 200=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 201=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 202=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 203=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 204=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 205=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 206=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 207=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 208=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 209=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 210=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 211=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 212=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 213=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 214=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 215=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 216=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 217=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 218=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 219=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 220=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 221=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 222=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 223=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 224=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 225=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 226=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 227=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 228=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 229=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 230=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 231=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 232=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 233=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 234=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 235=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 236=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 237=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 238=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 239=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 240=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 241=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 242=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 243=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 244=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 245=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 246=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 247=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 248=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 249=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 250=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 251=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 252=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 253=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 254=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 255=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 256=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 257=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 258=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 259=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 260=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 261=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 262=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 263=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 264=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 265=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 266=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 267=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 268=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 269=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 270=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 271=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 272=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 273=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 274=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 275=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 276=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 277=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 278=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 279=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 280=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 281=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 282=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 283=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 284=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 285=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 286=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 287=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 288=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 289=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 290=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 291=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 292=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 293=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 294=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 295=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 296=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 297=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 298=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# =========Generation 299=========
# Best Point:[0.6671212 0.6901032] with score -1.0
# Number of Clusters containing root: 12
#
# Roots:
# [[-6.43716259  0.15534788]
#  [-6.2        -0.16104581]
#  [-6.4         0.15618943]
#  [-6.1171134  -0.16347552]
#  [-1.          1.        ]
#  [-0.93212205  1.06787439]
#  [-0.15618944  6.4       ]
#  [-0.15528339  6.43983572]
#  [ 0.16333346  6.12243408]
#  [ 0.16104471  6.20003412]
#  [ 0.6         0.76085395]
#  [ 0.6671212   0.6901032 ]]
#
# Values:
# [-0.9999999999999996, -0.925783703322619, -0.9634437854222444, -0.9999999999999998, -0.8807970768891287, -0.9999999999999998, -0.9608124195016879, -0.9999999999999998, -0.9999999999999996, -0.9298597445361899, -0.8876055984772291, -1.0]

# %%
"""Choosing Best Solution"""
if dim == 1:
    list_criteria = [element for sublist in archive for element in sublist] #convert from 2D array into 1D array
else:
    list_criteria = archive
eligible_roots = np.array([x for x in list_criteria if (objective_function(x))<-1+epsilon])
id_duplicated_roots = []
for i in range(len(eligible_roots)):
    for j in range (i+1,len(eligible_roots)):
        if np.linalg.norm(eligible_roots[i]-eligible_roots[j])<delta:
            id_duplicated_roots.append([i,j])
id_duplicated_roots = np.unique(id_duplicated_roots,axis=0)
deselected_id_duplicated_roots = []
for i in range (len(id_duplicated_roots)):
    root_a = objective_function(eligible_roots[id_duplicated_roots[i][0]])
    root_b = objective_function(eligible_roots[id_duplicated_roots[i][1]])
    if root_a<=root_b:
        id_duplicated_root = id_duplicated_roots[i][1]
    else:
        id_duplicated_root = id_duplicated_roots[i][0]
    deselected_id_duplicated_roots.append(id_duplicated_root)

if deselected_id_duplicated_roots:
    unique_roots = np.ones(len(eligible_roots),dtype=bool)
    unique_roots[deselected_id_duplicated_roots] = False
    final_root = eligible_roots[unique_roots]
else:
    final_root = eligible_roots
print(final_root)
# Out:
# [[-6.43716259  0.15534788]
#  [-6.1171134  -0.16347552]
#  [-0.93212205  1.06787439]
#  [-0.15528339  6.43983572]
#  [ 0.16333346  6.12243408]
#  [ 0.6671212   0.6901032 ]]
