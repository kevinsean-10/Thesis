# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
pd.options.display.min_rows = 10
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 12  # You can also set the default font size

# %% [markdown]
# # Data 1

# %%
data1 = pd.read_excel('Analisis Problem.xlsx',sheet_name="Problem 1 - Roots",header=1)
data1
# Out:
#     pop_size  max_gen  roots found  count  percentage  Unnamed: 5  parts  \
# 0         50       50            0    110        1.00         NaN     50
# 1         50       50            1      0        0.00         NaN     50
# 2         50       50            2      0        0.00         NaN     50
# 3         50       50            3      0        0.00         NaN     50
# 4         50       50            4      0        0.00         NaN     50
# ..       ...      ...          ...    ...         ...         ...    ...
# 58       250      250            2      0        0.00         NaN    250
# 59       250      250            3     11        0.10         NaN    250
# 60       250      250            4     33        0.30         NaN    250
# 61       250      250            5     45        0.41         NaN    250
# 62       250      250            6     21        0.19         NaN    250
#
#     max_gen.1  roots found.1  count.1  percentage.1  Unnamed: 11  m_cluster  \
# ...

# %%
data1_rade = data1.iloc[:,:5]
data1_rade.rename(inplace=True,columns={'max_gen':"Maks Iter"})
data1_rade['percentage'] *= 100
popsize = [50,100,250]
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
cmap = sns.diverging_palette(145, 300, s=60,l=60,center='dark', as_cmap=True)
for id_popsize in range(len(popsize)):
    data1_rade_param = data1_rade.loc[(data1_rade['pop_size']==popsize[id_popsize])]
    sns.barplot(data1_rade_param,ax=axes[id_popsize],x="roots found", y="percentage",hue="Maks Iter",palette=cmap)
    axes[id_popsize].set(xlabel='Solusi yang ditemukan', ylabel='Persentase', title=f"Populasi {popsize[id_popsize]}")
    axes[id_popsize].set_ylim(0, 100)
fig.savefig(f'D:/OneDrive - Institut Teknologi Bandung/[AKADEMIK]/Semester 7-8/TA/Draft/Draft Buku/Gambar/Stat/Masalah 1/RADE, Masalah 1, Distribusi Akar.png')

# %%
data1_hde = data1.iloc[:,6:11]
data1_hde.rename(inplace=True,columns={'max_gen.1':"Maks Iter"})
data1_hde['percentage.1'] *= 100
popsize = [50,100,250]
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
cmap = sns.diverging_palette(145, 300, s=60,l=60,center='dark', as_cmap=True)
for id_popsize in range(len(popsize)):
    data1_hde_param = data1_hde.loc[(data1_hde['parts']==popsize[id_popsize])]
    sns.barplot(data1_hde_param,ax=axes[id_popsize],x="roots found.1", y="percentage.1",hue="Maks Iter",palette=cmap)
    axes[id_popsize].set(xlabel='Solusi yang ditemukan', ylabel='Persentase', title=f"Populasi {popsize[id_popsize]}")
    axes[id_popsize].set_ylim(0, 100)
fig.savefig(f'D:/OneDrive - Institut Teknologi Bandung/[AKADEMIK]/Semester 7-8/TA/Draft/Draft Buku/Gambar/Stat/Masalah 1/HDE, Masalah 1, Distribusi Akar.png')

# %%
data1_sdde = data1.iloc[:,12:]
data1_sdde.rename(inplace=True,columns={'k_max':"Maks Iter"})
data1_sdde['percentage.2'] *= 100
popsize = [50,100,250]
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
cmap = sns.diverging_palette(145, 300, s=60,l=60,center='dark', as_cmap=True)
for id_popsize in range(len(popsize)):
    data1_sdde_param = data1_sdde.loc[(data1_sdde['m_cluster']==popsize[id_popsize])]
    sns.barplot(data1_sdde_param,ax=axes[id_popsize],x="roots found.2", y="percentage.2",hue="Maks Iter",palette=cmap)
    axes[id_popsize].set(xlabel='Solusi yang ditemukan', ylabel='Persentase', title=f"Populasi {popsize[id_popsize]}")
    axes[id_popsize].set_ylim(0, 100)
fig.savefig(f'D:/OneDrive - Institut Teknologi Bandung/[AKADEMIK]/Semester 7-8/TA/Draft/Draft Buku/Gambar/Stat/Masalah 1/SDDE, Masalah 1, Distribusi Akar.png')

# %% [markdown]
# # Data 2

# %%
data2 = pd.read_excel('Analisis Problem.xlsx',sheet_name="Problem 2 - Roots",header=1)
data2
# Out:
#      pop_size  max_gen  roots found  count  percentage  Unnamed: 5  parts  \
# 0         100      100            0    110         1.0         NaN    100
# 1         100      100            1      0         0.0         NaN    100
# 2         100      100            2      0         0.0         NaN    100
# 3         100      100            3      0         0.0         NaN    100
# 4         100      100            4      0         0.0         NaN    100
# ..        ...      ...          ...    ...         ...         ...    ...
# 112      2000      300            8      0         0.0         NaN   2000
# 113      2000      300            9      0         0.0         NaN   2000
# 114      2000      300           10      0         0.0         NaN   2000
# 115      2000      300           11      0         0.0         NaN   2000
# 116      2000      300           12    110         1.0         NaN   2000
#
#      max_gen.1  roots found.1  count.1  percentage.1  Unnamed: 11  m_cluster  \
# ...

# %%
data2_rade = data2.iloc[:,:5]
data2_rade.rename(inplace=True,columns={'max_gen':"Maks Iter"})
data2_rade['percentage'] *= 100
popsize = [100,500,2000]
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
cmap = sns.diverging_palette(145, 300, s=60,l=60,center='dark', as_cmap=True)
for id_popsize in range(len(popsize)):
    data2_rade_param = data2_rade.loc[(data2_rade['pop_size']==popsize[id_popsize])]
    sns.barplot(data2_rade_param,ax=axes[id_popsize],x="roots found", y="percentage",hue="Maks Iter",palette=cmap)
    axes[id_popsize].set(xlabel='Solusi yang ditemukan', ylabel='Persentase', title=f"Populasi {popsize[id_popsize]}")
    axes[id_popsize].set_ylim(0, 100)
fig.savefig(f'D:/OneDrive - Institut Teknologi Bandung/[AKADEMIK]/Semester 7-8/TA/Draft/Draft Buku/Gambar/Stat/Masalah 2/RADE, Masalah 2, Distribusi Akar.png')

# %%
data2_hde = data2.iloc[:,6:11]
data2_hde.rename(inplace=True,columns={'max_gen.1':"Maks Iter"})
data2_hde['percentage.1'] *= 100
popsize = [100,500,2000]
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
cmap = sns.diverging_palette(145, 300, s=60,l=60,center='dark', as_cmap=True)
for id_popsize in range(len(popsize)):
    data2_hde_param = data2_hde.loc[(data2_hde['parts']==popsize[id_popsize])]
    sns.barplot(data2_hde_param,ax=axes[id_popsize],x="roots found.1", y="percentage.1",hue="Maks Iter",palette=cmap)
    axes[id_popsize].set(xlabel='Solusi yang ditemukan', ylabel='Persentase', title=f"Populasi {popsize[id_popsize]}")
    axes[id_popsize].set_ylim(0, 100)

fig.savefig(f'D:/OneDrive - Institut Teknologi Bandung/[AKADEMIK]/Semester 7-8/TA/Draft/Draft Buku/Gambar/Stat/Masalah 2/HDE, Masalah 2, Distribusi Akar.png')

# %%
data2_sdde = data2.iloc[:,12:]
data2_sdde.rename(inplace=True,columns={'k_max':"Maks Iter"})
data2_sdde['percentage.2'] *= 100
popsize = [100,500,2000]
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
cmap = sns.diverging_palette(145, 300, s=60,l=60,center='dark', as_cmap=True)
for id_popsize in range(len(popsize)):
    data2_sdde_param = data2_sdde.loc[(data2_sdde['m_cluster']==popsize[id_popsize])]
    sns.barplot(data2_sdde_param,ax=axes[id_popsize],x="roots found.2", y="percentage.2",hue="Maks Iter",palette=cmap)
    axes[id_popsize].set(xlabel='Solusi yang ditemukan', ylabel='Persentase', title=f"Populasi {popsize[id_popsize]}")
    axes[id_popsize].set_ylim(0, 100)

fig.savefig(f'D:/OneDrive - Institut Teknologi Bandung/[AKADEMIK]/Semester 7-8/TA/Draft/Draft Buku/Gambar/Stat/Masalah 2/SDDE, Masalah 2, Distribusi Akar.png')

# %% [markdown]
# # Data 3

# %%
data3 = pd.read_excel('Analisis Problem.xlsx',sheet_name="Problem 7 - Roots",header=1)
data3.head()
# Out:
#    pop_size  max_gen  roots found  count  percentage  Unnamed: 5  parts  \
# 0       100      100            0    110         1.0         NaN    100
# 1       100      100            1      0         0.0         NaN    100
# 2       100      100            2      0         0.0         NaN    100
# 3       100      100            3      0         0.0         NaN    100
# 4       100      100            4      0         0.0         NaN    100
#
#    max_gen.1  roots found.1  count.1  percentage.1  Unnamed: 11  m_cluster  \
# 0        100              0       20          0.18          NaN        100
# 1        100              1       49          0.45          NaN        100
# 2        100              2       33          0.30          NaN        100
# 3        100              3        7          0.06          NaN        100
# 4        100              4        1          0.01          NaN        100
#
#    k_max  roots found.2  count.2  percentage.2
# ...

# %%
data3_rade = data3.iloc[:,:5]
data3_rade.rename(inplace=True,columns={'max_gen':"Maks Iter"})
data3_rade['percentage'] *= 100
popsize = [100,250,400]
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
cmap = sns.diverging_palette(145, 300, s=60,l=60,center='dark', as_cmap=True)
for id_popsize in range(len(popsize)):
    data3_rade_param = data3_rade.loc[(data3_rade['pop_size']==popsize[id_popsize])]
    sns.barplot(data3_rade_param,ax=axes[id_popsize],x="roots found", y="percentage",hue="Maks Iter",palette=cmap)
    axes[id_popsize].set(xlabel='Solusi yang ditemukan', ylabel='Persentase', title=f"Populasi {popsize[id_popsize]}")
    axes[id_popsize].set_ylim(0, 100)
fig.savefig(f'D:/OneDrive - Institut Teknologi Bandung/[AKADEMIK]/Semester 7-8/TA/Draft/Draft Buku/Gambar/Stat/Masalah 3/RADE, Masalah 3, Distribusi Akar.png')

# %%
data3_hde = data3.iloc[:,6:11]
data3_hde.rename(inplace=True,columns={'max_gen.1':"Maks Iter"})
data3_hde['percentage.1'] *= 100
popsize = [100,250,400]
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
cmap = sns.diverging_palette(145, 300, s=60,l=60,center='dark', as_cmap=True)
for id_popsize in range(len(popsize)):
    data3_hde_param = data3_hde.loc[(data3_hde['parts']==popsize[id_popsize])]
    sns.barplot(data3_hde_param,ax=axes[id_popsize],x="roots found.1", y="percentage.1",hue="Maks Iter",palette=cmap)
    axes[id_popsize].set(xlabel='Solusi yang ditemukan', ylabel='Persentase', title=f"Populasi {popsize[id_popsize]}")
    axes[id_popsize].set_ylim(0, 100)

fig.savefig(f'D:/OneDrive - Institut Teknologi Bandung/[AKADEMIK]/Semester 7-8/TA/Draft/Draft Buku/Gambar/Stat/Masalah 3/HDE, Masalah 3, Distribusi Akar.png')

# %%
data3_sdde = data3.iloc[:,12:]
data3_sdde.rename(inplace=True,columns={'k_max':"Maks Iter"})
data3_sdde['percentage.2'] *= 100
popsize = [100,250,400]
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
cmap = sns.diverging_palette(145, 300, s=60,l=60,center='dark', as_cmap=True)
for id_popsize in range(len(popsize)):
    data3_sdde_param = data3_sdde.loc[(data3_sdde['m_cluster']==popsize[id_popsize])]
    sns.barplot(data3_sdde_param,ax=axes[id_popsize],x="roots found.2", y="percentage.2",hue="Maks Iter",palette=cmap)
    axes[id_popsize].set(xlabel='Solusi yang ditemukan', ylabel='Persentase', title=f"Populasi {popsize[id_popsize]}")
    axes[id_popsize].set_ylim(0, 100)

fig.savefig(f'D:/OneDrive - Institut Teknologi Bandung/[AKADEMIK]/Semester 7-8/TA/Draft/Draft Buku/Gambar/Stat/Masalah 3/SDDE, Masalah 3, Distribusi Akar.png')
