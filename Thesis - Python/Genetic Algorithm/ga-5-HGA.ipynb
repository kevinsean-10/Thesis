# %%
import numpy as np
from itertools import product,combinations
import matplotlib.pyplot as plt

# %% [markdown]
# Problem 1 Pak Kun

# %%
epsilon = 1e-2
delta = 0.01
m = 100
gen_max = 300
dim = 2
p_mutation = 0.1
seed = 0

# how many parts/slices do you desire in each dimension?
parts = 100

def system_eq(x):
    f1 = np.exp(x[0]-x[1])-np.sin(x[0]+x[1])
    f2 = (x[0]*x[1])**2-np.cos(x[0]+x[1])
    return np.array([f1,f2])

boundaries = np.array([(-10,10) for _ in range (dim)])

# %% [markdown]
# # Objective Function

# %%
def objective_function(x:np.ndarray):
    F_array = system_eq(x)
    denom = 0
    for f in F_array:
        denom +=np.abs(f)
    F = 1/(1+denom)
    return -F

# %%
def slice_hypercube(lower_bounds, upper_bounds, interval):
    dim = len(lower_bounds)
    # Create a list of arrays, each containing points spaced h apart for each dimension
    points = np.array([np.arange(lower_bounds[i], upper_bounds[i], interval[i]) for i in range(dim)])
    
    # Use meshgrid to create a grid of points in n-dimensional space
    grids = np.array(np.meshgrid(*points, indexing='ij'))
    
    # Flatten and combine the grid points into a single 2D array
    grid_points = np.vstack([grid.ravel() for grid in grids]).T
    
    # Generate all vertices for smaller hypercubes within each grid cell
    offsets = np.array(list(product(*[[0, val] for val in interval])))
    res = np.array([grid_points + offset for offset in offsets])
    return res

# %%
# length of each parts in each dimension
inc_int = (boundaries[:,1]-boundaries[:,0])/parts

# Hypercubes
hypercubes_edges = slice_hypercube(lower_bounds=boundaries[:,0],
                                   upper_bounds=boundaries[:,1],
                                   interval=inc_int)
# hypercubes_edges

# %%
cluster = []
for hypercube_id in range(hypercubes_edges.shape[1]):
    X0 = hypercubes_edges[:,hypercube_id,:]
    F_list = system_eq(X0.T)

    # cek jika f yang berubah tanda dari F_list jika dievaluasi di tiap edge hypercube
    product_combination = np.array([[a*b for a,b in combinations(F_list[i],2)] for i in range (F_list.shape[0])])

    # jika semua f dari F_list berubah tanda jika dievaluasi di tiap edge hypercube, maka ada akar di situ
    change_sign = np.array([np.any(product_combination[i]<0) for i in range (product_combination.shape[0])])
    if np.all(change_sign==True):
        # print(f'Ada akar di sini: \nX0={X0}')
        cluster.append(X0)

cluster = np.array(cluster)
print(f"Number of clusters containing root: {cluster.shape[0]}")
# Out:
# [[[-6.60000000e+00 -3.55271368e-14]
#   [-6.60000000e+00  2.00000000e-01]
#   [-6.40000000e+00 -3.55271368e-14]
#   [-6.40000000e+00  2.00000000e-01]]
#
#  [[-6.40000000e+00 -2.00000000e-01]
#   [-6.40000000e+00 -3.48054918e-14]
#   [-6.20000000e+00 -2.00000000e-01]
#   [-6.20000000e+00 -3.48054918e-14]]
#
#  [[-6.40000000e+00 -3.55271368e-14]
#   [-6.40000000e+00  2.00000000e-01]
#   [-6.20000000e+00 -3.55271368e-14]
#   [-6.20000000e+00  2.00000000e-01]]
#
#  [[-6.20000000e+00 -2.00000000e-01]
#   [-6.20000000e+00 -3.48054918e-14]
#   [-6.00000000e+00 -2.00000000e-01]
#   [-6.00000000e+00 -3.48054918e-14]]
#
#  [[-1.20000000e+00  1.00000000e+00]
#   [-1.20000000e+00  1.20000000e+00]
#   [-1.00000000e+00  1.00000000e+00]
#   [-1.00000000e+00  1.20000000e+00]]
#
#  [[-1.00000000e+00  1.00000000e+00]
#   [-1.00000000e+00  1.20000000e+00]
#   [-8.00000000e-01  1.00000000e+00]
#   [-8.00000000e-01  1.20000000e+00]]
#
#  [[-2.00000000e-01  6.20000000e+00]
#   [-2.00000000e-01  6.40000000e+00]
#   [-3.48054918e-14  6.20000000e+00]
#   [-3.48054918e-14  6.40000000e+00]]
#
#  [[-2.00000000e-01  6.40000000e+00]
#   [-2.00000000e-01  6.60000000e+00]
#   [-3.48054918e-14  6.40000000e+00]
#   [-3.48054918e-14  6.60000000e+00]]
#
#  [[-3.55271368e-14  6.00000000e+00]
#   [-3.55271368e-14  6.20000000e+00]
#   [ 2.00000000e-01  6.00000000e+00]
#   [ 2.00000000e-01  6.20000000e+00]]
#
#  [[-3.55271368e-14  6.20000000e+00]
#   [-3.55271368e-14  6.40000000e+00]
#   [ 2.00000000e-01  6.20000000e+00]
#   [ 2.00000000e-01  6.40000000e+00]]
#
#  [[ 4.00000000e-01  6.00000000e-01]
#   [ 4.00000000e-01  8.00000000e-01]
#   [ 6.00000000e-01  6.00000000e-01]
#   [ 6.00000000e-01  8.00000000e-01]]
#
#  [[ 6.00000000e-01  6.00000000e-01]
#   [ 6.00000000e-01  8.00000000e-01]
#   [ 8.00000000e-01  6.00000000e-01]
#   [ 8.00000000e-01  8.00000000e-01]]]
# Number of clusters containing root: 12

# %% [markdown]
# # GA Evaluation

# %%
import importlib
import re

import sys
module_path = r"D:\OneDrive - Institut Teknologi Bandung\[AKADEMIK]\Semester 7-8\TA\Thesis\Genetic Algorithm"
sys.path.append(module_path)
import genal as gal
importlib.reload(gal)

sys.path.remove(module_path)

# %%
roots = []
values = []
for i in range (cluster.shape[0]):
    subbound = np.array([[cluster[i,:,:][:,d].min(),cluster[i,:,:][:,d].max()] for d in range(cluster.shape[2])])
    root,value = gal.GA(objective_function=objective_function,
                        population_size=m,
                        boundaries=subbound,
                        max_generation=gen_max,
                        mutation_rate=p_mutation,
                        seed=0,
                        print_stat=True)
    roots.append(root)
    values.append(value)

archive = np.array(roots)
scores = np.array(values)
print(f'Number of Clusters containing root: {cluster.shape[0]}\n')
print(f'Roots:\n{archive}\n\nValues: \n{values}')
# Out:
# =========Generation 0=========
# Best Individual: [-6.42066422  0.1565967 ]
# Best Score: -0.971961763334752
#
# =========Generation 1=========
# Best Individual: [-6.43513451  0.15566445]
# Best Score: -0.9942379428230547
#
# =========Generation 2=========
# Best Individual: [-6.43513451  0.15566445]
# Best Score: -0.9942379428230547
#
# =========Generation 3=========
# Best Individual: [-6.43513451  0.15566445]
# Best Score: -0.9942379428230547
#
# =========Generation 4=========
# Best Individual: [-6.43513451  0.15566445]
# Best Score: -0.9942379428230547
#
# =========Generation 5=========
# Best Individual: [-6.43780365  0.15566445]
# Best Score: -0.9954185120945308
#
# =========Generation 6=========
# Best Individual: [-6.43780365  0.15566445]
# Best Score: -0.9954185120945308
#
# =========Generation 7=========
# Best Individual: [-6.43780365  0.15566445]
# Best Score: -0.9954185120945308
#
# =========Generation 8=========
# Best Individual: [-6.43780365  0.15566445]
# Best Score: -0.9954185120945308
#
# =========Generation 9=========
# Best Individual: [-6.43780365  0.15566445]
# Best Score: -0.9954185120945308
# c:\Users\ACER\AppData\Local\Programs\Python\Python38\lib\site-packages\scipy\stats\_qmc.py:763: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# =========Generation 10=========
# Best Individual: [-6.43780365  0.15566445]
# Best Score: -0.9954185120945308
#
# =========Generation 11=========
# Best Individual: [-6.43780365  0.15566445]
# Best Score: -0.9954185120945308
#
# =========Generation 12=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation 13=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation 14=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation 15=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation 16=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation 17=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation 18=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation 19=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation 20=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation 21=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation 22=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation 23=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation 24=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation 25=========
# Best Individual: [-6.43794185  0.15566445]
# Best Score: -0.9952392134483176
#
# =========Generation
#
# =========Generation 7=========
# Best Individual: [-6.20613196 -0.16127534]
# Best Score: -0.9158935238331901
#
# =========Generation 8=========
# Best Individual: [-6.21083489 -0.16127534]
# Best Score: -0.9103905578497242
#
# =========Generation 9=========
# Best Individual: [-6.21840507 -0.15996586]
# Best Score: -0.906322134908508
#
# =========Generation 10=========
# Best Individual: [-6.20613196 -0.16127534]
# Best Score: -0.9158935238331901
#
# =========Generation 11=========
# Best Individual: [-6.20750376 -0.15996586]
# Best Score: -0.9116004142271205
#
# =========Generation 12=========
# Best Individual: [-6.20750376 -0.15996586]
# Best Score: -0.9116004142271205
#
# =========Generation 13=========
# Best Individual: [-6.20750376 -0.16127534]
# Best Score: -0.9142833416099155
#
# =========Generation 14=========
# Best Individual: [-6.2013244  -0.15996586]
# Best Score: -0.9146697043617137
#
# =========Generation 15=========
# Best Individual: [-6.20750376 -0.15996586]
# Best Score: -0.9116004142271205
#
# =========Generation 16=========
# Best Individual: [-6.2013244  -0.15996586]
# Best Score: -0.9146697043617137
#
# =========Generation 17=========
# Best Individual: [-6.2013244  -0.15996586]
# Best Score: -0.9146697043617137
#
# =========Generation 18=========
# Best Individual: [-6.20613196 -0.15996586]
# Best Score: -0.912276914362262
#
# =========Generation 19=========
# Best Individual: [-6.2013244  -0.15996586]
# Best Score: -0.9146697043617137
#
# =========Generation 20=========
# Best Individual: [-6.2013244  -0.15996586]
# Best Score: -0.9146697043617137
#
# =========Generation 21=========
# Best Individual: [-6.20054312 -0.15996586]
# Best Score: -0.9150618040268041
#
# =========Generation 22=========
# Best Individual: [-6.2013244  -0.15996586]
# Best Score: -0.9146697043617137
#
# =========Generation 23=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 24=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 25=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 26=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 27=========
# Best Individual: [-6.2013244  -0.15996586]
# Best Score: -0.9146697043617137
#
# =========Generation 28=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 29=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 30=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 31=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 32=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 33=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 34=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 35=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 36=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 37=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 38=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 39=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 40=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 41=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 42=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 43=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 44=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 45=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 46=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 47=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 48=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 49=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 50=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 51=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 52=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 53=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 54=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 55=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 56=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 57=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 58=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 59=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 60=========
# Best Individual: [-6.20017964 -0.16099329]
# Best Score: -0.9251766774715362
#
# =========Generation 61=========
# Best Individual: [-6.20135983 -0.16099329]
# Best Score: -0.9245764125087522
#
# =========Generation 62=========
# Best Individual: [-6.2013244  -0.16099329]
# Best Score: -0.9245944001635441
#
# =========Generation 63=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 64=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 65=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 66=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 67=========
# Best Individual: [-6.20135983 -0.16107201]
# Best Score: -0.9238599429826907
#
# =========Generation 68=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 69=========
# Best Individual: [-6.20017964 -0.16142363]
# Best Score: -0.9212285362508421
#
# =========Generation 70=========
# Best Individual: [-6.20017964 -0.16142363]
# Best Score: -0.9212285362508421
#
# =========Generation 71=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 72=========
# Best Individual: [-6.20017964 -0.15996586]
# Best Score: -0.9152445274291349
#
# =========Generation 73=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 74=========
# Best Individual: [-6.2013244  -0.16050744]
# Best Score: -0.9198658067431452
#
# =========Generation 75=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 76=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 77=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 78=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 79=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 80=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 81=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 82=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 83=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 84=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 85=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 86=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 87=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 88=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 89=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 90=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 91=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 92=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 93=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 94=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 95=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 96=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 97=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 98=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 99=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 100=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 101=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 102=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 103=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 104=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 105=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 106=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 107=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 108=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 109=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 110=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 111=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 112=========
# Best Individual: [-6.20017964 -0.16050744]
# Best Score: -0.9204445281161572
#
# =========Generation 113=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 114=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 115=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 116=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 117=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 118=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 119=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 120=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 121=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 122=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 123=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 124=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 125=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 126=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 127=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 128=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 129=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 130=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 131=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 132=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 133=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 134=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 135=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 136=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 137=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 138=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 139=========
# Best Individual: [-6.20017964 -0.16082779]
# Best Score: -0.9235574636326842
#
# =========Generation 140=========
# ...
# Best Score: -0.9995695369881201
#
# =========Generation 157=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 158=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 159=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 160=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 161=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 162=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 163=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 164=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 165=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 166=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 167=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 168=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 169=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 170=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 171=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 172=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 173=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 174=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 175=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 176=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 177=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 178=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 179=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 180=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 181=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 182=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 183=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 184=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 185=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 186=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 187=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 188=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 189=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 190=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 191=========
# Best Individual: [0.66726154 0.68990864]
# Best Score: -0.9995779816191102
#
# =========Generation 192=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 193=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 194=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 195=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 196=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 197=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 198=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 199=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 200=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 201=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 202=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 203=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 204=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 205=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 206=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 207=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 208=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 209=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 210=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 211=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 212=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 213=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 214=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 215=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 216=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 217=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 218=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 219=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 220=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 221=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 222=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 223=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 224=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 225=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 226=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 227=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 228=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 229=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 230=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 231=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 232=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 233=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 234=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 235=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 236=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 237=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 238=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 239=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 240=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 241=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 242=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 243=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 244=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 245=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 246=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 247=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 248=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 249=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 250=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 251=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 252=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 253=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 254=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 255=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 256=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 257=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 258=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 259=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 260=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 261=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 262=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 263=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 264=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 265=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 266=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 267=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 268=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 269=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 270=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 271=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 272=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 273=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 274=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 275=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 276=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 277=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 278=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 279=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 280=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 281=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 282=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 283=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 284=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 285=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 286=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 287=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 288=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 289=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 290=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 291=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 292=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 293=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 294=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 295=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 296=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 297=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 298=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# =========Generation 299=========
# Best Individual: [0.66733519 0.68990864]
# Best Score: -0.9995695369881201
#
# Number of Clusters containing root: 12
#
# Roots:
# [[-6.43751468  0.15566445]
#  [-6.20017964 -0.16056815]
#  [-6.3982067   0.15667711]
#  [-6.11736654 -0.16334539]
#  [-1.00270561  1.00083472]
#  [-0.93699878  1.06306665]
#  [-0.15622582  6.39958293]
#  [-0.15528234  6.43983731]
#  [ 0.16327412  6.12279967]
#  [ 0.16068612  6.20083472]
#  [ 0.59951283  0.75975078]
#  [ 0.66733519  0.68990864]]
#
# Values:
# [-0.9957935822054389, -0.9210323357547197, -0.9560238387250155, -0.9983715295476681, -0.8742577979031148, -0.9903658813406039, -0.9600681555654155, -0.9999843740501985, -0.999087169314513, -0.9259101378107116, -0.8863161513328629, -0.9995695369881201]

# %%
"""Choosing Best Solution"""
if dim == 1:
    list_criteria = [element for sublist in archive for element in sublist] #convert from 2D array into 1D array
else:
    list_criteria = archive
eligible_roots = np.array([x for x in list_criteria if (objective_function(x))<-1+epsilon])
id_duplicated_roots = []
for i in range(len(eligible_roots)):
    for j in range (i+1,len(eligible_roots)):
        if np.linalg.norm(eligible_roots[i]-eligible_roots[j])<delta:
            id_duplicated_roots.append([i,j])
id_duplicated_roots = np.unique(id_duplicated_roots,axis=0)
deselected_id_duplicated_roots = []
for i in range (len(id_duplicated_roots)):
    root_a = objective_function(eligible_roots[id_duplicated_roots[i][0]])
    root_b = objective_function(eligible_roots[id_duplicated_roots[i][1]])
    if root_a<=root_b:
        id_duplicated_root = id_duplicated_roots[i][1]
    else:
        id_duplicated_root = id_duplicated_roots[i][0]
    deselected_id_duplicated_roots.append(id_duplicated_root)

if deselected_id_duplicated_roots:
    unique_roots = np.ones(len(eligible_roots),dtype=bool)
    unique_roots[deselected_id_duplicated_roots] = False
    final_root = eligible_roots[unique_roots]
else:
    final_root = eligible_roots
print(final_root)
# Out:
# [[-6.43751468  0.15566445]
#  [-6.11736654 -0.16334539]
#  [-0.93699878  1.06306665]
#  [-0.15528234  6.43983731]
#  [ 0.16327412  6.12279967]
#  [ 0.66733519  0.68990864]]
